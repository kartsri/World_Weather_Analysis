# %%
# Import dependencies
from citipy import citipy
import pandas as pd
import numpy as np
import json 
import requests
import timeit

from datetime import datetime
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 750

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25d38e422a25052620a67beb790e3e5e

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | athabasca
# Processing Record 3 of Set 1 | nikolskoye
# Processing Record 4 of Set 1 | katherine
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | itarema
# Processing Record 8 of Set 1 | axim
# Processing Record 9 of Set 1 | san angelo
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | kapaa
# Processing Record 14 of Set 1 | stephenville
# Processing Record 15 of Set 1 | berdigestyakh
# Processing Record 16 of Set 1 | ola
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 1 | carnarvon
# Processing Record 20 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 1 | khatanga
# Processing Record 22 of Set 1 | vrutky
# Processing Record 23 of Set 1 | butaritari
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | lilongwe
# Processing Record 26 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 1 | kavaratti
# Processing Record 28 of Set 1 | katsuura
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | mareeba
# Processing Record 31 of Set 1 | novobelokatay
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | bandarbeyla
# Processing Record 34 of Set 1 | kiruna
# Processing Record 35 of Set 1 | badarpur
# Processing Record 36 of Set 1 | erzin
# Processing Record 37 of Set 1 | bereda
# Processing Record 38 of Set 1 | mataura
# Processing Record 39 of Set 1 | aklavik
# Processing Record 40 of Set 1 | faanui
# Processing Record 41 of Set 1 | narsaq
# Processing Record 42 of Set 1 | zhezkazgan
# Processing Record 43 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 1 | mar del plata
# Processing Record 45 of Set 1 | maceio
# Processing Record 46 of Set 1 | linares
# Processing Record 47 of Set 1 | babati
# Processing Record 48 of Set 1 | ganjam
# Processing Record 49 of Set 1 | georgetown
# Processing Record 50 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 2 | mahebourg
# Processing Record 2 of Set 2 | new norfolk
# Processing Record 3 of Set 2 | akureyri
# Processing Record 4 of Set 2 | honiara
# Processing Record 5 of Set 2 | busselton
# Processing Record 6 of Set 2 | kuching
# Processing Record 7 of Set 2 | arraial do cabo
# Processing Record 8 of Set 2 | kortkeros
# Processing Record 9 of Set 2 | asyut
# Processing Record 10 of Set 2 | guerrero negro
# Processing Record 11 of Set 2 | hambantota
# Processing Record 12 of Set 2 | muisne
# Processing Record 13 of Set 2 | atuona
# Processing Record 14 of Set 2 | kodiak
# Processing Record 15 of Set 2 | clyde river
# Processing Record 16 of Set 2 | ribeira grande
# Processing Record 17 of Set 2 | pailon
# Processing Record 18 of Set 2 | yerbogachen
# Processing Record 19 of Set 2 | santa cruz
# Processing Record 20 of Set 2 | abomey
# Processing Record 21 of Set 2 | kathmandu
# Processing Record 22 of Set 2 | hovd
# Processing Record 23 of Set 2 | aden
# Processing Record 24 of Set 2 | chuy
# Processing Record 25 of Set 2 | banjar
# Processing Record 26 of Set 2 | saint-philippe
# Processing Record 27 of Set 2 | sitka
# Processing Record 28 of Set 2 | cayenne
# Processing Record 29 of Set 2 | lompoc
# Processing Record 30 of Set 2 | kongolo
# Processing Record 31 of Set 2 | sagae
# Processing Record 32 of Set 2 | juxian
# City not found. Skipping...
# Processing Record 33 of Set 2 | tuktoyaktuk
# Processing Record 34 of Set 2 | suhbaatar
# Processing Record 35 of Set 2 | ahipara
# Processing Record 36 of Set 2 | saint george
# Processing Record 37 of Set 2 | mackay
# Processing Record 38 of Set 2 | mitzic
# Processing Record 39 of Set 2 | punta arenas
# Processing Record 40 of Set 2 | bloomfield
# Processing Record 41 of Set 2 | bethel
# Processing Record 42 of Set 2 | skotina
# Processing Record 43 of Set 2 | kanash
# Processing Record 44 of Set 2 | saldanha
# Processing Record 45 of Set 2 | hilo
# Processing Record 46 of Set 2 | weihe
# Processing Record 47 of Set 2 | petauke
# Processing Record 48 of Set 2 | flin flon
# Processing Record 49 of Set 2 | margate
# Processing Record 50 of Set 2 | huilong
# Processing Record 1 of Set 3 | churapcha
# Processing Record 2 of Set 3 | naze
# Processing Record 3 of Set 3 | tasiilaq
# Processing Record 4 of Set 3 | urumqi
# Processing Record 5 of Set 3 | kahului
# Processing Record 6 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 7 of Set 3 | jumla
# Processing Record 8 of Set 3 | bluff
# Processing Record 9 of Set 3 | alofi
# Processing Record 10 of Set 3 | saskylakh
# Processing Record 11 of Set 3 | severo-kurilsk
# Processing Record 12 of Set 3 | pevek
# Processing Record 13 of Set 3 | seddon
# Processing Record 14 of Set 3 | clarence town
# Processing Record 15 of Set 3 | cao bang
# Processing Record 16 of Set 3 | fortuna
# Processing Record 17 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 3 | ponta do sol
# Processing Record 19 of Set 3 | roald
# Processing Record 20 of Set 3 | prince rupert
# Processing Record 21 of Set 3 | lusambo
# Processing Record 22 of Set 3 | castro
# Processing Record 23 of Set 3 | lata
# Processing Record 24 of Set 3 | brylivka
# Processing Record 25 of Set 3 | port hardy
# Processing Record 26 of Set 3 | ambilobe
# Processing Record 27 of Set 3 | camacupa
# Processing Record 28 of Set 3 | beyneu
# Processing Record 29 of Set 3 | tandil
# Processing Record 30 of Set 3 | evora
# Processing Record 31 of Set 3 | mehamn
# Processing Record 32 of Set 3 | sulangan
# Processing Record 33 of Set 3 | batagay-alyta
# Processing Record 34 of Set 3 | namatanai
# Processing Record 35 of Set 3 | thompson
# Processing Record 36 of Set 3 | beipiao
# Processing Record 37 of Set 3 | korla
# Processing Record 38 of Set 3 | seredka
# Processing Record 39 of Set 3 | pacific grove
# Processing Record 40 of Set 3 | hong gai
# Processing Record 41 of Set 3 | tete
# Processing Record 42 of Set 3 | talnakh
# Processing Record 43 of Set 3 | vestmannaeyjar
# Processing Record 44 of Set 3 | dedza
# Processing Record 45 of Set 3 | sri aman
# Processing Record 46 of Set 3 | carlsbad
# Processing Record 47 of Set 3 | nemuro
# Processing Record 48 of Set 3 | puerto boyaca
# Processing Record 49 of Set 3 | hithadhoo
# Processing Record 50 of Set 3 | broken hill
# Processing Record 1 of Set 4 | chokurdakh
# Processing Record 2 of Set 4 | buala
# Processing Record 3 of Set 4 | caravelas
# Processing Record 4 of Set 4 | nanortalik
# Processing Record 5 of Set 4 | sao filipe
# Processing Record 6 of Set 4 | okha
# Processing Record 7 of Set 4 | isangel
# Processing Record 8 of Set 4 | dukat
# Processing Record 9 of Set 4 | vardo
# Processing Record 10 of Set 4 | barrow
# Processing Record 11 of Set 4 | cabo san lucas
# Processing Record 12 of Set 4 | luderitz
# Processing Record 13 of Set 4 | pitimbu
# Processing Record 14 of Set 4 | bredasdorp
# Processing Record 15 of Set 4 | brazzaville
# Processing Record 16 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 4 | palmer
# Processing Record 18 of Set 4 | sao joao da barra
# Processing Record 19 of Set 4 | bonavista
# Processing Record 20 of Set 4 | damnagar
# Processing Record 21 of Set 4 | rundu
# Processing Record 22 of Set 4 | araouane
# Processing Record 23 of Set 4 | komsomolskiy
# Processing Record 24 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 4 | hanzhong
# Processing Record 26 of Set 4 | mount isa
# Processing Record 27 of Set 4 | deep river
# Processing Record 28 of Set 4 | sokolka
# Processing Record 29 of Set 4 | dunedin
# Processing Record 30 of Set 4 | bubaque
# Processing Record 31 of Set 4 | east london
# Processing Record 32 of Set 4 | tura
# Processing Record 33 of Set 4 | cumberland
# Processing Record 34 of Set 4 | ippy
# Processing Record 35 of Set 4 | qaanaaq
# Processing Record 36 of Set 4 | vila
# Processing Record 37 of Set 4 | taoudenni
# Processing Record 38 of Set 4 | upernavik
# Processing Record 39 of Set 4 | kruisfontein
# Processing Record 40 of Set 4 | den helder
# Processing Record 41 of Set 4 | slawno
# Processing Record 42 of Set 4 | milyutinskaya
# Processing Record 43 of Set 4 | upata
# Processing Record 44 of Set 4 | manta
# Processing Record 45 of Set 4 | avarua
# Processing Record 46 of Set 4 | provideniya
# Processing Record 47 of Set 4 | kampong thum
# Processing Record 48 of Set 4 | victoria
# Processing Record 49 of Set 4 | mount gambier
# Processing Record 50 of Set 4 | airai
# Processing Record 1 of Set 5 | yar-sale
# Processing Record 2 of Set 5 | christchurch
# Processing Record 3 of Set 5 | norman wells
# Processing Record 4 of Set 5 | sakakah
# Processing Record 5 of Set 5 | strezhevoy
# Processing Record 6 of Set 5 | tatawin
# Processing Record 7 of Set 5 | san quintin
# Processing Record 8 of Set 5 | kaitangata
# Processing Record 9 of Set 5 | pontal do parana
# Processing Record 10 of Set 5 | nome
# Processing Record 11 of Set 5 | saint-pierre
# Processing Record 12 of Set 5 | yellowknife
# Processing Record 13 of Set 5 | kindu
# Processing Record 14 of Set 5 | bambous virieux
# Processing Record 15 of Set 5 | ewa beach
# Processing Record 16 of Set 5 | tiksi
# Processing Record 17 of Set 5 | tezu
# Processing Record 18 of Set 5 | kidal
# Processing Record 19 of Set 5 | lagoa
# Processing Record 20 of Set 5 | siguiri
# Processing Record 21 of Set 5 | novyy urgal
# Processing Record 22 of Set 5 | tessalit
# Processing Record 23 of Set 5 | gaomi
# Processing Record 24 of Set 5 | iramuco
# Processing Record 25 of Set 5 | san pedro de cajas
# Processing Record 26 of Set 5 | abong mbang
# Processing Record 27 of Set 5 | zabol
# Processing Record 28 of Set 5 | warah
# Processing Record 29 of Set 5 | ancud
# Processing Record 30 of Set 5 | el carmen
# Processing Record 31 of Set 5 | shingu
# Processing Record 32 of Set 5 | cape town
# Processing Record 33 of Set 5 | great yarmouth
# Processing Record 34 of Set 5 | egvekinot
# Processing Record 35 of Set 5 | port hedland
# Processing Record 36 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 5 | la raya de santa maria
# Processing Record 38 of Set 5 | byron bay
# Processing Record 39 of Set 5 | fevralsk
# City not found. Skipping...
# Processing Record 40 of Set 5 | laguna
# Processing Record 41 of Set 5 | kusye-aleksandrovskiy
# City not found. Skipping...
# Processing Record 42 of Set 5 | longyearbyen
# Processing Record 43 of Set 5 | kudahuvadhoo
# Processing Record 44 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 45 of Set 5 | dingle
# Processing Record 46 of Set 5 | baruun-urt
# Processing Record 47 of Set 5 | nortelandia
# Processing Record 48 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 49 of Set 5 | iqaluit
# Processing Record 50 of Set 5 | dikson
# Processing Record 1 of Set 6 | yeppoon
# Processing Record 2 of Set 6 | pathalgaon
# Processing Record 3 of Set 6 | lebu
# Processing Record 4 of Set 6 | raymondville
# Processing Record 5 of Set 6 | hobyo
# Processing Record 6 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 6 | bartica
# Processing Record 8 of Set 6 | champerico
# Processing Record 9 of Set 6 | lazaro cardenas
# Processing Record 10 of Set 6 | naples
# Processing Record 11 of Set 6 | port elizabeth
# Processing Record 12 of Set 6 | gao
# Processing Record 13 of Set 6 | dubbo
# Processing Record 14 of Set 6 | cleethorpes
# Processing Record 15 of Set 6 | hami
# Processing Record 16 of Set 6 | mandera
# Processing Record 17 of Set 6 | port-gentil
# Processing Record 18 of Set 6 | puerto del rosario
# Processing Record 19 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 20 of Set 6 | chernyshevskiy
# Processing Record 21 of Set 6 | jacmel
# Processing Record 22 of Set 6 | coquimbo
# Processing Record 23 of Set 6 | eirunepe
# Processing Record 24 of Set 6 | bela
# Processing Record 25 of Set 6 | mao
# Processing Record 26 of Set 6 | adelaide
# Processing Record 27 of Set 6 | hofn
# Processing Record 28 of Set 6 | rawlins
# Processing Record 29 of Set 6 | kirakira
# Processing Record 30 of Set 6 | hamilton
# Processing Record 31 of Set 6 | manado
# Processing Record 32 of Set 6 | sola
# Processing Record 33 of Set 6 | zastron
# Processing Record 34 of Set 6 | ayios matthaios
# City not found. Skipping...
# Processing Record 35 of Set 6 | morgan city
# Processing Record 36 of Set 6 | vao
# Processing Record 37 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 6 | dachau
# Processing Record 39 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 40 of Set 6 | waw
# Processing Record 41 of Set 6 | chabahar
# Processing Record 42 of Set 6 | nordborg
# Processing Record 43 of Set 6 | demba
# Processing Record 44 of Set 6 | ahuimanu
# Processing Record 45 of Set 6 | stalowa wola
# Processing Record 46 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 6 | tarakan
# Processing Record 48 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 49 of Set 6 | emerald
# Processing Record 50 of Set 6 | manvi
# Processing Record 1 of Set 7 | palu
# Processing Record 2 of Set 7 | zaidpur
# Processing Record 3 of Set 7 | wufeng
# Processing Record 4 of Set 7 | sept-iles
# Processing Record 5 of Set 7 | torbay
# Processing Record 6 of Set 7 | saint-pascal
# City not found. Skipping...
# Processing Record 7 of Set 7 | north bend
# Processing Record 8 of Set 7 | halenkov
# Processing Record 9 of Set 7 | andenes
# Processing Record 10 of Set 7 | umm ruwabah
# City not found. Skipping...
# Processing Record 11 of Set 7 | ketchikan
# Processing Record 12 of Set 7 | roma
# Processing Record 13 of Set 7 | kieta
# Processing Record 14 of Set 7 | bosanski brod
# Processing Record 15 of Set 7 | la ronge
# Processing Record 16 of Set 7 | bull savanna
# Processing Record 17 of Set 7 | kargasok
# Processing Record 18 of Set 7 | lasa
# Processing Record 19 of Set 7 | baghdad
# Processing Record 20 of Set 7 | sembe
# Processing Record 21 of Set 7 | sinnamary
# Processing Record 22 of Set 7 | makarov
# Processing Record 23 of Set 7 | abaza
# Processing Record 24 of Set 7 | bengkulu
# Processing Record 25 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 26 of Set 7 | sao geraldo do araguaia
# Processing Record 27 of Set 7 | limoeiro do ajuru
# Processing Record 28 of Set 7 | hasaki
# Processing Record 29 of Set 7 | zeya
# Processing Record 30 of Set 7 | jaslo
# Processing Record 31 of Set 7 | wloclawek
# Processing Record 32 of Set 7 | arkhipo-osipovka
# Processing Record 33 of Set 7 | gulshat
# City not found. Skipping...
# Processing Record 34 of Set 7 | genhe
# Processing Record 35 of Set 7 | rangapara
# Processing Record 36 of Set 7 | hualmay
# Processing Record 37 of Set 7 | marang
# Processing Record 38 of Set 7 | ocos
# Processing Record 39 of Set 7 | sangar
# Processing Record 40 of Set 7 | bathsheba
# Processing Record 41 of Set 7 | san isidro
# Processing Record 42 of Set 7 | ustrzyki dolne
# Processing Record 43 of Set 7 | ilulissat
# Processing Record 44 of Set 7 | richards bay
# Processing Record 45 of Set 7 | yulara
# Processing Record 46 of Set 7 | esperance
# Processing Record 47 of Set 7 | inirida
# Processing Record 48 of Set 7 | rio grande
# Processing Record 49 of Set 7 | sinjai
# Processing Record 50 of Set 7 | sioux lookout
# Processing Record 1 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 2 of Set 8 | nishihara
# Processing Record 3 of Set 8 | san patricio
# Processing Record 4 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 5 of Set 8 | marawi
# Processing Record 6 of Set 8 | nhulunbuy
# Processing Record 7 of Set 8 | waddan
# Processing Record 8 of Set 8 | borujan
# City not found. Skipping...
# Processing Record 9 of Set 8 | tongzi
# Processing Record 10 of Set 8 | cidreira
# Processing Record 11 of Set 8 | varna
# Processing Record 12 of Set 8 | skagastrond
# City not found. Skipping...
# Processing Record 13 of Set 8 | aripuana
# Processing Record 14 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 8 | namie
# Processing Record 16 of Set 8 | hirara
# Processing Record 17 of Set 8 | bullhead city
# Processing Record 18 of Set 8 | mnogovershinnyy
# Processing Record 19 of Set 8 | corrente
# Processing Record 20 of Set 8 | puerto leguizamo
# Processing Record 21 of Set 8 | saint-georges
# Processing Record 22 of Set 8 | los llanos de aridane
# Processing Record 23 of Set 8 | beringovskiy
# Processing Record 24 of Set 8 | port blair
# Processing Record 25 of Set 8 | iwanai
# Processing Record 26 of Set 8 | teguldet
# Processing Record 27 of Set 8 | bani walid
# Processing Record 28 of Set 8 | mahajanga
# Processing Record 29 of Set 8 | warrnambool
# Processing Record 30 of Set 8 | sedelnikovo
# City not found. Skipping...
# Processing Record 31 of Set 8 | porto novo
# Processing Record 32 of Set 8 | lanciano
# Processing Record 33 of Set 8 | jijiga
# Processing Record 34 of Set 8 | poitiers
# Processing Record 35 of Set 8 | erenhot
# Processing Record 36 of Set 8 | huaihua
# Processing Record 37 of Set 8 | udala
# Processing Record 38 of Set 8 | borogontsy
# Processing Record 39 of Set 8 | srednekolymsk
# Processing Record 40 of Set 8 | maracaju
# Processing Record 41 of Set 8 | dakar
# Processing Record 42 of Set 8 | adrar
# Processing Record 43 of Set 8 | pandan niog
# Processing Record 44 of Set 8 | majene
# Processing Record 45 of Set 8 | gisborne
# Processing Record 46 of Set 8 | college
# Processing Record 47 of Set 8 | nelson bay
# Processing Record 48 of Set 8 | chicama
# Processing Record 49 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 8 | krasnyy chikoy
# Processing Record 1 of Set 9 | moyale
# Processing Record 2 of Set 9 | sabla
# Processing Record 3 of Set 9 | krasnoselkup
# Processing Record 4 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 9 | whitehorse
# Processing Record 6 of Set 9 | comodoro rivadavia
# Processing Record 7 of Set 9 | alihe
# Processing Record 8 of Set 9 | berlevag
# Processing Record 9 of Set 9 | westport
# Processing Record 10 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 11 of Set 9 | greenwood
# Processing Record 12 of Set 9 | cortes
# Processing Record 13 of Set 9 | fairbanks
# Processing Record 14 of Set 9 | anar darreh
# City not found. Skipping...
# Processing Record 15 of Set 9 | san cristobal
# Processing Record 16 of Set 9 | tres arroyos
# Processing Record 17 of Set 9 | winnemucca
# Processing Record 18 of Set 9 | waipawa
# Processing Record 19 of Set 9 | okato
# Processing Record 20 of Set 9 | akhty
# Processing Record 21 of Set 9 | fredonia
# Processing Record 22 of Set 9 | bloomington
# Processing Record 23 of Set 9 | olovyannaya
# Processing Record 24 of Set 9 | tigil
# Processing Record 25 of Set 9 | quatre cocos
# Processing Record 26 of Set 9 | namibe
# Processing Record 27 of Set 9 | atambua
# Processing Record 28 of Set 9 | carauari
# Processing Record 29 of Set 9 | puerto colombia
# Processing Record 30 of Set 9 | almaznyy
# Processing Record 31 of Set 9 | mumford
# Processing Record 32 of Set 9 | gobabis
# Processing Record 33 of Set 9 | narrabri
# Processing Record 34 of Set 9 | miraflores
# Processing Record 35 of Set 9 | portland
# Processing Record 36 of Set 9 | adwa
# Processing Record 37 of Set 9 | ternate
# Processing Record 38 of Set 9 | verdun
# Processing Record 39 of Set 9 | tilichiki
# Processing Record 40 of Set 9 | puerto ayacucho
# Processing Record 41 of Set 9 | kavieng
# Processing Record 42 of Set 9 | kysyl-syr
# Processing Record 43 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 9 | pisco
# Processing Record 45 of Set 9 | ahar
# Processing Record 46 of Set 9 | geraldton
# Processing Record 47 of Set 9 | fort-shevchenko
# Processing Record 48 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 9 | belmonte
# Processing Record 50 of Set 9 | alice springs
# Processing Record 1 of Set 10 | smidovich
# Processing Record 2 of Set 10 | antigonish
# Processing Record 3 of Set 10 | henties bay
# Processing Record 4 of Set 10 | nagato
# Processing Record 5 of Set 10 | praia
# Processing Record 6 of Set 10 | zhangye
# Processing Record 7 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 8 of Set 10 | cherskiy
# Processing Record 9 of Set 10 | deputatskiy
# Processing Record 10 of Set 10 | saint-augustin
# Processing Record 11 of Set 10 | peshkovo
# Processing Record 12 of Set 10 | oudtshoorn
# Processing Record 13 of Set 10 | lufilufi
# Processing Record 14 of Set 10 | turangi
# Processing Record 15 of Set 10 | maniitsoq
# Processing Record 16 of Set 10 | monteagudo
# Processing Record 17 of Set 10 | mana
# Processing Record 18 of Set 10 | oktyabrskoye
# Processing Record 19 of Set 10 | ust-nera
# Processing Record 20 of Set 10 | klaksvik
# Processing Record 21 of Set 10 | salacgriva
# Processing Record 22 of Set 10 | niceville
# Processing Record 23 of Set 10 | kupang
# Processing Record 24 of Set 10 | pachino
# Processing Record 25 of Set 10 | gumdag
# Processing Record 26 of Set 10 | binga
# Processing Record 27 of Set 10 | micheweni
# Processing Record 28 of Set 10 | gushikawa
# Processing Record 29 of Set 10 | palmas
# Processing Record 30 of Set 10 | asadabad
# Processing Record 31 of Set 10 | abu dhabi
# Processing Record 32 of Set 10 | oksfjord
# Processing Record 33 of Set 10 | qasigiannguit
# Processing Record 34 of Set 10 | victoria point
# Processing Record 35 of Set 10 | yanchukan
# City not found. Skipping...
# Processing Record 36 of Set 10 | thohoyandou
# Processing Record 37 of Set 10 | ulu-telyak
# Processing Record 38 of Set 10 | rostovka
# Processing Record 39 of Set 10 | jacareacanga
# Processing Record 40 of Set 10 | morant bay
# Processing Record 41 of Set 10 | kodinsk
# Processing Record 42 of Set 10 | touros
# Processing Record 43 of Set 10 | souillac
# Processing Record 44 of Set 10 | carmona
# Processing Record 45 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 46 of Set 10 | nouakchott
# Processing Record 47 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 10 | angostura
# Processing Record 49 of Set 10 | polonnaruwa
# Processing Record 50 of Set 10 | maningrida
# Processing Record 1 of Set 11 | naftah
# City not found. Skipping...
# Processing Record 2 of Set 11 | chihuahua
# Processing Record 3 of Set 11 | north platte
# Processing Record 4 of Set 11 | mahbubabad
# Processing Record 5 of Set 11 | mandalgovi
# Processing Record 6 of Set 11 | salaga
# Processing Record 7 of Set 11 | mentok
# City not found. Skipping...
# Processing Record 8 of Set 11 | kagadi
# Processing Record 9 of Set 11 | lavrentiya
# Processing Record 10 of Set 11 | viedma
# Processing Record 11 of Set 11 | kobayashi
# Processing Record 12 of Set 11 | trinidad
# Processing Record 13 of Set 11 | bonthe
# Processing Record 14 of Set 11 | celestun
# Processing Record 15 of Set 11 | erdenet
# Processing Record 16 of Set 11 | san carlos de bariloche
# Processing Record 17 of Set 11 | bolshaya irba
# City not found. Skipping...
# Processing Record 18 of Set 11 | yarada
# Processing Record 19 of Set 11 | faya
# Processing Record 20 of Set 11 | paamiut
# Processing Record 21 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 22 of Set 11 | parabel
# Processing Record 23 of Set 11 | salalah
# Processing Record 24 of Set 11 | bud
# Processing Record 25 of Set 11 | hastings
# Processing Record 26 of Set 11 | syracuse
# Processing Record 27 of Set 11 | najran
# Processing Record 28 of Set 11 | wajid
# Processing Record 29 of Set 11 | andevoranto
# City not found. Skipping...
# Processing Record 30 of Set 11 | cockburn town
# Processing Record 31 of Set 11 | koltsovo
# Processing Record 32 of Set 11 | nabire
# Processing Record 33 of Set 11 | tuatapere
# Processing Record 34 of Set 11 | warrington
# Processing Record 35 of Set 11 | moron
# Processing Record 36 of Set 11 | anloga
# Processing Record 37 of Set 11 | sorong
# Processing Record 38 of Set 11 | kuytun
# Processing Record 39 of Set 11 | tommot
# Processing Record 40 of Set 11 | pergamino
# Processing Record 41 of Set 11 | laurinburg
# Processing Record 42 of Set 11 | san jose de rio tinto
# Processing Record 43 of Set 11 | cherkasskoye
# Processing Record 44 of Set 11 | vaitape
# Processing Record 45 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 46 of Set 11 | mikhaylovka
# Processing Record 47 of Set 11 | koumac
# Processing Record 48 of Set 11 | turukhansk
# Processing Record 49 of Set 11 | shitanjing
# Processing Record 50 of Set 11 | kaniama
# Processing Record 1 of Set 12 | paidha
# Processing Record 2 of Set 12 | buraydah
# Processing Record 3 of Set 12 | kharovsk
# Processing Record 4 of Set 12 | okhotsk
# Processing Record 5 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 6 of Set 12 | somerset east
# Processing Record 7 of Set 12 | lubaczow
# Processing Record 8 of Set 12 | poshekhonye
# Processing Record 9 of Set 12 | taltal
# Processing Record 10 of Set 12 | pilao arcado
# City not found. Skipping...
# Processing Record 11 of Set 12 | burns lake
# Processing Record 12 of Set 12 | corinto
# Processing Record 13 of Set 12 | freire
# Processing Record 14 of Set 12 | wangou
# Processing Record 15 of Set 12 | plettenberg bay
# Processing Record 16 of Set 12 | quelimane
# Processing Record 17 of Set 12 | covington
# Processing Record 18 of Set 12 | tocopilla
# Processing Record 19 of Set 12 | camacari
# Processing Record 20 of Set 12 | sorland
# Processing Record 21 of Set 12 | tooele
# Processing Record 22 of Set 12 | vila franca do campo
# Processing Record 23 of Set 12 | roshchino
# Processing Record 24 of Set 12 | letka
# Processing Record 25 of Set 12 | gidam
# Processing Record 26 of Set 12 | doha
# Processing Record 27 of Set 12 | havre-saint-pierre
# Processing Record 28 of Set 12 | zhigansk
# Processing Record 29 of Set 12 | garowe
# Processing Record 30 of Set 12 | zhaoyuan
# Processing Record 31 of Set 12 | guarapari
# Processing Record 32 of Set 12 | gat
# Processing Record 33 of Set 12 | kutum
# Processing Record 34 of Set 12 | bilgoraj
# Processing Record 35 of Set 12 | polyanka
# Processing Record 36 of Set 12 | poum
# Processing Record 37 of Set 12 | tupik
# Processing Record 38 of Set 12 | yomou
# Processing Record 39 of Set 12 | santa rosa
# Processing Record 40 of Set 12 | beloha
# Processing Record 41 of Set 12 | veshenskaya
# Processing Record 42 of Set 12 | mogadishu
# Processing Record 43 of Set 12 | ostrovnoy
# Processing Record 44 of Set 12 | half moon bay
# Processing Record 45 of Set 12 | mabaruma
# Processing Record 46 of Set 12 | ayni
# Processing Record 47 of Set 12 | gigmoto
# Processing Record 48 of Set 12 | visnes
# Processing Record 49 of Set 12 | ayer itam
# City not found. Skipping...
# Processing Record 50 of Set 12 | gravdal
# Processing Record 1 of Set 13 | bikapur
# Processing Record 2 of Set 13 | raiganj
# Processing Record 3 of Set 13 | longonjo
# Processing Record 4 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 5 of Set 13 | nioro
# Processing Record 6 of Set 13 | morondava
# Processing Record 7 of Set 13 | hun
# Processing Record 8 of Set 13 | blagoveshchenka
# Processing Record 9 of Set 13 | constitucion
# Processing Record 10 of Set 13 | alpena
# Processing Record 11 of Set 13 | groningen
# Processing Record 12 of Set 13 | ust-barguzin
# Processing Record 13 of Set 13 | udachnyy
# Processing Record 14 of Set 13 | saint-joseph
# Processing Record 15 of Set 13 | calama
# Processing Record 16 of Set 13 | codrington
# Processing Record 17 of Set 13 | kaitong
# Processing Record 18 of Set 13 | tateyama
# Processing Record 19 of Set 13 | walvis bay
# Processing Record 20 of Set 13 | pagman
# City not found. Skipping...
# Processing Record 21 of Set 13 | riyadh
# Processing Record 22 of Set 13 | amahai
# Processing Record 23 of Set 13 | lokosovo
# Processing Record 24 of Set 13 | ayagoz
# Processing Record 25 of Set 13 | chake chake
# Processing Record 26 of Set 13 | karratha
# Processing Record 27 of Set 13 | gornopravdinsk
# Processing Record 28 of Set 13 | sembakung
# Processing Record 29 of Set 13 | jati
# Processing Record 30 of Set 13 | leningradskiy
# Processing Record 31 of Set 13 | sahrak
# City not found. Skipping...
# Processing Record 32 of Set 13 | shubarshi
# Processing Record 33 of Set 13 | sungurlu
# Processing Record 34 of Set 13 | derzhavinsk
# Processing Record 35 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 36 of Set 13 | sisimiut
# Processing Record 37 of Set 13 | mayo
# Processing Record 38 of Set 13 | sterling
# Processing Record 39 of Set 13 | malmesbury
# Processing Record 40 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 41 of Set 13 | beian
# Processing Record 42 of Set 13 | northam
# Processing Record 43 of Set 13 | belaya gora
# Processing Record 44 of Set 13 | iralaya
# Processing Record 45 of Set 13 | kungsbacka
# Processing Record 46 of Set 13 | matamoros
# Processing Record 47 of Set 13 | minab
# Processing Record 48 of Set 13 | harper
# Processing Record 49 of Set 13 | tigzirt
# Processing Record 50 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 14 | hervey bay
# Processing Record 2 of Set 14 | biskamzha
# Processing Record 3 of Set 14 | sarospatak
# Processing Record 4 of Set 14 | ewo
# Processing Record 5 of Set 14 | labuhan
# Processing Record 6 of Set 14 | olafsvik
# Processing Record 7 of Set 14 | tadine
# Processing Record 8 of Set 14 | vanimo
# Processing Record 9 of Set 14 | immokalee
# Processing Record 10 of Set 14 | banda aceh
# Processing Record 11 of Set 14 | puerto escondido
# Processing Record 12 of Set 14 | le port
# Processing Record 13 of Set 14 | luba
# Processing Record 14 of Set 14 | candolim
# Processing Record 15 of Set 14 | mayumba
# Processing Record 16 of Set 14 | guacimo
# Processing Record 17 of Set 14 | burica
# City not found. Skipping...
# Processing Record 18 of Set 14 | thunder bay
# Processing Record 19 of Set 14 | farsund
# Processing Record 20 of Set 14 | otjimbingwe
# Processing Record 21 of Set 14 | pedernales
# Processing Record 22 of Set 14 | chippewa falls
# Processing Record 23 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 24 of Set 14 | dogondoutchi
# Processing Record 25 of Set 14 | san juan
# Processing Record 26 of Set 14 | kiunga
# Processing Record 27 of Set 14 | marsh harbour
# Processing Record 28 of Set 14 | macaboboni
# City not found. Skipping...
# Processing Record 29 of Set 14 | gebre guracha
# Processing Record 30 of Set 14 | nanticoke
# Processing Record 31 of Set 14 | ixtapa
# Processing Record 32 of Set 14 | fort morgan
# Processing Record 33 of Set 14 | santiago
# Processing Record 34 of Set 14 | bima
# Processing Record 35 of Set 14 | karauzyak
# City not found. Skipping...
# Processing Record 36 of Set 14 | calvia
# Processing Record 37 of Set 14 | sobolevo
# Processing Record 38 of Set 14 | yumen
# Processing Record 39 of Set 14 | wajima
# Processing Record 40 of Set 14 | prabumulih
# Processing Record 41 of Set 14 | ribeira brava
# Processing Record 42 of Set 14 | avera
# Processing Record 43 of Set 14 | corn island
# Processing Record 44 of Set 14 | shkotovo-22
# City not found. Skipping...
# Processing Record 45 of Set 14 | kamaishi
# Processing Record 46 of Set 14 | zhongshan
# Processing Record 47 of Set 14 | makokou
# Processing Record 48 of Set 14 | mingguang
# Processing Record 49 of Set 14 | grindavik
# Processing Record 50 of Set 14 | teguise
# Processing Record 1 of Set 15 | saint-francois
# Processing Record 2 of Set 15 | lagos
# Processing Record 3 of Set 15 | marystown
# Processing Record 4 of Set 15 | tazovskiy
# Processing Record 5 of Set 15 | wladyslawowo
# Processing Record 6 of Set 15 | nuuk
# Processing Record 7 of Set 15 | zelenoborskiy
# Processing Record 8 of Set 15 | catuday
# Processing Record 9 of Set 15 | bundaberg
# Processing Record 10 of Set 15 | ayan
# Processing Record 11 of Set 15 | smyrna
# Processing Record 12 of Set 15 | birao
# Processing Record 13 of Set 15 | santiago del estero
# Processing Record 14 of Set 15 | saquarema
# Processing Record 15 of Set 15 | matara
# Processing Record 16 of Set 15 | severomuysk
# Processing Record 17 of Set 15 | salekhard
# Processing Record 18 of Set 15 | iisalmi
# Processing Record 19 of Set 15 | argentan
# Processing Record 20 of Set 15 | kibala
# Processing Record 21 of Set 15 | brenham
# Processing Record 22 of Set 15 | mastung
# Processing Record 23 of Set 15 | kropotkin
# Processing Record 24 of Set 15 | pitkyaranta
# Processing Record 25 of Set 15 | baglung
# Processing Record 26 of Set 15 | skibotn
# Processing Record 27 of Set 15 | batagay
# Processing Record 28 of Set 15 | bulawayo
# Processing Record 29 of Set 15 | columbus
# Processing Record 30 of Set 15 | riachao
# Processing Record 31 of Set 15 | tapaua
# City not found. Skipping...
# Processing Record 32 of Set 15 | channel-port aux basques
# Processing Record 33 of Set 15 | waharoa
# Processing Record 34 of Set 15 | meulaboh
# Processing Record 35 of Set 15 | chimbote
# Processing Record 36 of Set 15 | susanville
# Processing Record 37 of Set 15 | krasnik
# Processing Record 38 of Set 15 | ust-kuyga
# Processing Record 39 of Set 15 | terra santa
# Processing Record 40 of Set 15 | takoradi
# Processing Record 41 of Set 15 | chapais
# Processing Record 42 of Set 15 | tromso
# Processing Record 43 of Set 15 | ullapool
# Processing Record 44 of Set 15 | jalu
# Processing Record 45 of Set 15 | bambanglipuro
# Processing Record 46 of Set 15 | loukhi
# Processing Record 47 of Set 15 | ambon
# Processing Record 48 of Set 15 | namtsy
# Processing Record 49 of Set 15 | tabas
# Processing Record 50 of Set 15 | kasra
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Port Alfred -33.5906   26.8910     55.72        72           4        5.19
# 1    Athabasca  54.7169 -113.2854     39.02        34          18        6.67
# 2   Nikolskoye  59.7035   30.7861     42.87        93           0        7.99
# 3    Katherine -14.4667  132.2667    102.52        24           0       10.36
# 4      Rikitea -23.1203 -134.9692     73.18        71          86       17.85
#
#   Country Current Description
# 0      ZA          light rain
# 1      CA          few clouds
# 2      RU           clear sky
# 3      AU           clear sky
# 4      PF          light rain

# %%
column_adjust = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[column_adjust]
city_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Port Alfred      ZA -33.5906   26.8910     55.72        72           4
# 1    Athabasca      CA  54.7169 -113.2854     39.02        34          18
# 2   Nikolskoye      RU  59.7035   30.7861     42.87        93           0
# 3    Katherine      AU -14.4667  132.2667    102.52        24           0
# 4      Rikitea      PF -23.1203 -134.9692     73.18        71          86
#
#    Wind Speed Current Description
# 0        5.19          light rain
# 1        6.67          few clouds
# 2        7.99           clear sky
# 3       10.36           clear sky
# 4       17.85          light rain
