# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 621

# %%
cities
# Out:
# ['barentsburg',
#  'bluff',
#  'padang',
#  'severo-yeniseyskiy',
#  'tommot',
#  'hofn',
#  'butaritari',
#  'taolanaro',
#  'puerto ayora',
#  'yellowknife',
#  'murray bridge',
#  'wairoa',
#  'anadyr',
#  'hobart',
#  'victoria',
#  'saint-philippe',
#  'katsuura',
#  'maldonado',
#  'mount isa',
#  'safaga',
#  'mitu',
#  'atuona',
#  'san cristobal',
#  'omboue',
#  'east london',
#  'dhidhdhoo',
#  'lorengau',
#  'carnarvon',
#  'rikitea',
#  'palabuhanratu',
#  'arraial do cabo',
#  'castro',
#  'hithadhoo',
#  'bambous virieux',
#  'ushuaia',
#  'albany',
#  'arlit',
#  'busselton',
#  'cape town',
#  'iskateley',
#  'georgetown',
#  'port hawkesbury',
#  'saskylakh',
#  'abyek',
#  'yagodnoye',
#  'avarua',
#  'ampanihy',
#  'inhambane',
#  'camocim',
#  'talnakh',
#  'vaitupu',
#  'fortuna',
#  'pogaceaua',
#  'okhotsk',
#  'lagoa',
#  'nanortalik',
#  'barabinsk',
#  'illoqqortoormiut',
#  'khatanga',
#  'chuy',
#  'punta arenas',
#  'halifax',
#  'vaini',
#  'vao',
#  'leh',
#  'cherskiy',
#  'amderma',
#  'grand gaube',
#  'neryungri',
#  'bahia honda',
#  'kaeo',
#  'quatre cocos',
#  'dwarka',
#  'cameron park',
#  'krasnokamensk',
#  'port alfred',
#  'thompson',
#  'ginda',
#  'college',
#  'distraccion',
#  'geraldton',
#  'aksay',
#  'atar',
#  'pevek',
#  'mandan',
#  'xai-xai',
#  'tuktoyaktuk',
#  'saldanha',
#  'meadow lake',
#  'jamestown',
#  'narragansett',
#  'chanika',
#  'warri',
#  'kotma',
#  'clyde river',
#  'guerrero negro',
#  'boende',
#  'at-bashi',
#  'cocal',
#  'kununurra',
#  'tiksi',
#  'tura',
#  'chokurdakh',
#  'biltine',
#  'kapaa',
#  'tawkar',
#  'prince rupert',
#  'belaya gora',
#  'nikolskoye',
#  'rawson',
#  'provideniya',
#  'coihaique',
#  'aanekoski',
#  'bogorodskoye',
#  'pacific grove',
#  'alofi',
#  'broken hill',
#  'saint-remi',
#  'bargal',
#  'san-pedro',
#  'urumqi',
#  'kadykchan',
#  'airai',
#  'miastko',
#  'aguimes',
#  'dikson',
#  'mataura',
#  'sychevka',
#  'verkhoyansk',
#  'opunake',
#  'mayo',
#  'kodiak',
#  'bonavista',
#  'sao jose da coroa grande',
#  'dir',
#  'tual',
#  'xiuyan',
#  'barrow',
#  'marcona',
#  'otane',
#  'upernavik',
#  'khonuu',
#  'cabedelo',
#  'qaanaaq',
#  'rochegda',
#  'magalia',
#  'cidreira',
#  'severnyy',
#  'oranjestad',
#  'natal',
#  'santa rosa',
#  'praia',
#  'saleaula',
#  'port elizabeth',
#  'hovd',
#  'presidencia roque saenz pena',
#  'garissa',
#  'meulaboh',
#  'ocos',
#  'tasiilaq',
#  'buraydah',
#  'hami',
#  'kruisfontein',
#  'sao filipe',
#  'hermanus',
#  'north bend',
#  'mar del plata',
#  'todos santos',
#  'port-cartier',
#  'gurskoye',
#  'hue',
#  'vestmannaeyjar',
#  'itarema',
#  'torbay',
#  'adrar',
#  'lewisville',
#  'chumikan',
#  'lumphat',
#  'magaria',
#  'ilulissat',
#  'kazalinsk',
#  'komsomolskiy',
#  'burica',
#  'oktyabrskiy',
#  'prescott',
#  'dingle',
#  'kaitangata',
#  'puerto del rosario',
#  'prainha',
#  'hibbing',
#  'phan rang',
#  'benguela',
#  'las palmas',
#  'vaasa',
#  'tabou',
#  'san patricio',
#  'pangnirtung',
#  'belushya guba',
#  'hilo',
#  'longyearbyen',
#  'irondequoit',
#  'seoul',
#  'axim',
#  'severo-kurilsk',
#  'manzhouli',
#  'nizhneyansk',
#  'hamilton',
#  'nemuro',
#  'bontang',
#  'new norfolk',
#  'bilibino',
#  'samusu',
#  'hambantota',
#  'olinda',
#  'sentyabrskiy',
#  'vanimo',
#  'lolua',
#  'mayor pablo lagerenza',
#  'luderitz',
#  'youkounkoun',
#  'hasaki',
#  'shaowu',
#  'mogadishu',
#  'viligili',
#  'ambilobe',
#  'tsaratanana',
#  'mersing',
#  'nome',
#  'matara',
#  'kalianget',
#  'bonthe',
#  'pesqueira',
#  'le port',
#  'kurchum',
#  'diamantina',
#  'bredasdorp',
#  'san jeronimo',
#  'dores do indaia',
#  'san policarpo',
#  'half moon bay',
#  'nouadhibou',
#  'walvis bay',
#  'charters towers',
#  'mimongo',
#  'pemberton',
#  'lavrentiya',
#  'sept-iles',
#  'warqla',
#  'san jose',
#  'kashi',
#  'mehamn',
#  'matale',
#  'bulgan',
#  'dhuwaran',
#  'beruwala',
#  'bani walid',
#  'tsihombe',
#  'codrington',
#  'ancud',
#  'faanui',
#  'ust-nera',
#  'husavik',
#  'sabinas hidalgo',
#  'kijang',
#  'attawapiskat',
#  'donskoye',
#  'tanout',
#  'tasbuget',
#  'ust-ilimsk',
#  'turukhansk',
#  'zyryanka',
#  'tarudant',
#  'zhaotong',
#  'aginskoye',
#  'souillac',
#  'gwadar',
#  'lebu',
#  'beloha',
#  'ilebo',
#  'kahului',
#  'ronne',
#  'narsaq',
#  'shache',
#  'morehead',
#  'acarau',
#  'ilhabela',
#  'burnie',
#  'kilindoni',
#  'sioux lookout',
#  'bud',
#  'anloga',
#  'pitimbu',
#  'vila franca do campo',
#  'bethel',
#  'yuksekova',
#  'noumea',
#  'mys shmidta',
#  'kabwe',
#  'olafsvik',
#  'omagari',
#  'ulverstone',
#  'progreso',
#  'darhan',
#  'iqaluit',
#  'chom bung',
#  'cao bang',
#  'poum',
#  'sarakhs',
#  'margate',
#  'xiongshi',
#  'manavalakurichi',
#  'ahar',
#  'chake chake',
#  'fuyu',
#  'paamiut',
#  'ribeira grande',
#  'saint-francois',
#  'sawakin',
#  'kropotkin',
#  'prokuplje',
#  'tuburan',
#  'ahumada',
#  'karamea',
#  'northam',
#  'laguna',
#  'saint george',
#  'koygorodok',
#  'sobolevo',
#  'tutoia',
#  'sulangan',
#  'maumere',
#  'taltal',
#  'aybak',
#  'octeville',
#  'sofiysk',
#  'mangit',
#  'panguna',
#  'kayerkan',
#  'tuatapere',
#  'caraballeda',
#  'warrnambool',
#  'roebourne',
#  'pochutla',
#  'belidzhi',
#  'skibotn',
#  'mahebourg',
#  'balsas',
#  'san quintin',
#  'svobodnyy',
#  'waingapu',
#  'vila velha',
#  'ostrovnoy',
#  'awbari',
#  'klaksvik',
#  'katangli',
#  'namatanai',
#  'agadez',
#  'morris',
#  'portland',
#  'ixtapa',
#  'marsh harbour',
#  'viseu',
#  'panzhihua',
#  'sambava',
#  'joshimath',
#  'areia branca',
#  'camanducaia',
#  'scottsbluff',
#  'jalu',
#  'lasa',
#  'sarahan',
#  'aktas',
#  'dickson',
#  'najran',
#  'sistranda',
#  'matay',
#  'loubomo',
#  'latehar',
#  'raga',
#  'sabha',
#  'aksarka',
#  'raglan',
#  'snasa',
#  'el alto',
#  'hong gai',
#  'brae',
#  'aransas pass',
#  'maragogi',
#  'gat',
#  'kalikino',
#  'batemans bay',
#  'owando',
#  'coahuayana',
#  'necochea',
#  'baykit',
#  'bengkulu',
#  'iraucuba',
#  'cardston',
#  'kualakapuas',
#  'haines junction',
#  'flin flon',
#  'finote selam',
#  'novoagansk',
#  'goderich',
#  'burkhala',
#  'wittstock',
#  'norman wells',
#  'vestmanna',
#  'tilichiki',
#  'mayumba',
#  'oriximina',
#  'roald',
#  'akdepe',
#  'iralaya',
#  'puerto escondido',
#  'izhma',
#  'kavieng',
#  'daokou',
#  'xining',
#  'touros',
#  'totness',
#  'mergui',
#  'bay roberts',
#  'tessalit',
#  'mana',
#  'grindavik',
#  'esperance',
#  'ati',
#  'roswell',
#  'mount gambier',
#  'dolbeau',
#  'bathsheba',
#  'salaga',
#  'kathmandu',
#  'huangzhai',
#  'salalah',
#  'ninotsminda',
#  'gambela',
#  'khash',
#  'hulan ergi',
#  'isfana',
#  'leningradskiy',
#  'nalut',
#  'namibe',
#  'tezu',
#  'tamano',
#  'panalingaan',
#  'bubaque',
#  'hoa binh',
#  'fairbanks',
#  'gobabis',
#  'balkhash',
#  'aklavik',
#  'port macquarie',
#  'dutse',
#  'buala',
#  'erzin',
#  'toliary',
#  'sitka',
#  'kamenka',
#  'eureka',
#  'ponta do sol',
#  'kismayo',
#  'sibolga',
#  'udachnyy',
#  'tanhacu',
#  'sorland',
#  'praia da vitoria',
#  'utiroa',
#  'te anau',
#  'zhigansk',
#  'primorsk',
#  'kenai',
#  'mumford',
#  'champerico',
#  'mount abu',
#  'tamazulapam',
#  'changji',
#  'sisimiut',
#  'salinopolis',
#  'ahipara',
#  'iquique',
#  'grants pass',
#  'chepen',
#  'harper',
#  'nizhniy odes',
#  'semirom',
#  'tateyama',
#  'cenade',
#  'lisakovsk',
#  'undory',
#  'saint-joseph',
#  'voi',
#  'belaya glina',
#  'corrente',
#  'mata de sao joao',
#  'vostok',
#  'balkanabat',
#  'berbera',
#  'marienburg',
#  'klamath falls',
#  'bocas del toro',
#  'ancona',
#  'estacion coahuila',
#  'antofagasta',
#  'freeport',
#  'pakxan',
#  'maniitsoq',
#  'saint stephen',
#  'aswan',
#  'kamenskoye',
#  'gao',
#  'tumannyy',
#  'kita',
#  'inderborskiy',
#  'lata',
#  'evensk',
#  'raudeberg',
#  'zaozerne',
#  'plettenberg bay',
#  'azrow',
#  'cayenne',
#  'hobyo',
#  'tabasalu',
#  'betlitsa',
#  'beipiao',
#  'kashan',
#  'bandarbeyla',
#  'skelleftea',
#  'porto nacional',
#  'constitucion',
#  'linhares',
#  'neuquen',
#  'mulege',
#  'svencioneliai',
#  'port-gentil',
#  'kendari',
#  'las vegas',
#  'chaa-khol',
#  'nantucket',
#  'sao joao da barra',
#  'iquitos',
#  'sorong',
#  'alice springs',
#  'dire',
#  'north platte',
#  'santo antonio do monte',
#  'port hedland',
#  'nicoya',
#  'verkh-usugli',
#  'cabo san lucas',
#  'omsukchan',
#  'harij',
#  'bukachacha',
#  'boa vista',
#  'hay river',
#  'caldas da rainha',
#  'srednekolymsk',
#  'felipe carrillo puerto',
#  'vila',
#  'mercedes',
#  'muravlenko',
#  'kosino',
#  'guajara-mirim',
#  'dzhebariki-khaya',
#  'korem',
#  'beringovskiy',
#  'loreto',
#  'hanzhong',
#  'ust-kamchatsk',
#  'nueva gerona',
#  'oussouye',
#  'tahe',
#  'rabat',
#  'kabin buri',
#  'iwaki',
#  'buin',
#  'greytown',
#  'panjab',
#  'magway',
#  'port lincoln',
#  'la ronge',
#  'dunedin',
#  'may pen',
#  'kango',
#  'kamaishi',
#  'urucara',
#  'leo',
#  'ishigaki',
#  'albanel',
#  'alpena',
#  'ayolas',
#  'marsa matruh',
#  'remontnoye',
#  'ponta delgada',
#  'mujiayingzi',
#  'weligama',
#  'sindou',
#  'lensk',
#  'ossora',
#  'bokspits',
#  'noyabrsk',
#  'los llanos de aridane',
#  'la romana',
#  'marawi',
#  'zirandaro',
#  'havelock',
#  'murska sobota',
#  'tongzi',
#  'bangkal',
#  'bodden town',
#  'aranos',
#  'nordfjordeid',
#  'porto novo',
#  'guasdualito',
#  'shilka',
#  'ketchikan',
#  'swedru',
#  'krasnoselkup',
#  'veydelevka',
#  'zhangye']

# %%
len(cities)
# Out:
# 621

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=25d38e422a25052620a67beb790e3e5e

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 60.28,
#   'feels_like': 60.1,
#   'temp_min': 56.62,
#   'temp_max': 63.43,
#   'pressure': 1016,
#   'humidity': 87},
#  'visibility': 10000,
#  'wind': {'speed': 1.01, 'deg': 92, 'gust': 8.01},
#  'clouds': {'all': 90},
#  'dt': 1633306583,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1633257816,
#   'sunset': 1633299753},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 63.43 87 90 1.01

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2021, 10, 4, 0, 16, 23)

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | padang
# Processing Record 4 of Set 1 | severo-yeniseyskiy
# Processing Record 5 of Set 1 | tommot
# Processing Record 6 of Set 1 | hofn
# Processing Record 7 of Set 1 | butaritari
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | puerto ayora
# Processing Record 10 of Set 1 | yellowknife
# Processing Record 11 of Set 1 | murray bridge
# Processing Record 12 of Set 1 | wairoa
# Processing Record 13 of Set 1 | anadyr
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | victoria
# Processing Record 16 of Set 1 | saint-philippe
# Processing Record 17 of Set 1 | katsuura
# Processing Record 18 of Set 1 | maldonado
# Processing Record 19 of Set 1 | mount isa
# Processing Record 20 of Set 1 | safaga
# Processing Record 21 of Set 1 | mitu
# Processing Record 22 of Set 1 | atuona
# Processing Record 23 of Set 1 | san cristobal
# Processing Record 24 of Set 1 | omboue
# Processing Record 25 of Set 1 | east london
# Processing Record 26 of Set 1 | dhidhdhoo
# Processing Record 27 of Set 1 | lorengau
# Processing Record 28 of Set 1 | carnarvon
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 1 | arraial do cabo
# Processing Record 32 of Set 1 | castro
# Processing Record 33 of Set 1 | hithadhoo
# Processing Record 34 of Set 1 | bambous virieux
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | albany
# Processing Record 37 of Set 1 | arlit
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | iskateley
# Processing Record 41 of Set 1 | georgetown
# Processing Record 42 of Set 1 | port hawkesbury
# Processing Record 43 of Set 1 | saskylakh
# Processing Record 44 of Set 1 | abyek
# Processing Record 45 of Set 1 | yagodnoye
# Processing Record 46 of Set 1 | avarua
# Processing Record 47 of Set 1 | ampanihy
# Processing Record 48 of Set 1 | inhambane
# Processing Record 49 of Set 1 | camocim
# Processing Record 50 of Set 1 | talnakh
# Processing Record 1 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 2 | fortuna
# Processing Record 3 of Set 2 | pogaceaua
# Processing Record 4 of Set 2 | okhotsk
# Processing Record 5 of Set 2 | lagoa
# Processing Record 6 of Set 2 | nanortalik
# Processing Record 7 of Set 2 | barabinsk
# Processing Record 8 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 2 | khatanga
# Processing Record 10 of Set 2 | chuy
# Processing Record 11 of Set 2 | punta arenas
# Processing Record 12 of Set 2 | halifax
# Processing Record 13 of Set 2 | vaini
# Processing Record 14 of Set 2 | vao
# Processing Record 15 of Set 2 | leh
# Processing Record 16 of Set 2 | cherskiy
# Processing Record 17 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 2 | grand gaube
# Processing Record 19 of Set 2 | neryungri
# Processing Record 20 of Set 2 | bahia honda
# Processing Record 21 of Set 2 | kaeo
# Processing Record 22 of Set 2 | quatre cocos
# Processing Record 23 of Set 2 | dwarka
# Processing Record 24 of Set 2 | cameron park
# Processing Record 25 of Set 2 | krasnokamensk
# Processing Record 26 of Set 2 | port alfred
# Processing Record 27 of Set 2 | thompson
# Processing Record 28 of Set 2 | ginda
# Processing Record 29 of Set 2 | college
# Processing Record 30 of Set 2 | distraccion
# Processing Record 31 of Set 2 | geraldton
# Processing Record 32 of Set 2 | aksay
# Processing Record 33 of Set 2 | atar
# Processing Record 34 of Set 2 | pevek
# Processing Record 35 of Set 2 | mandan
# Processing Record 36 of Set 2 | xai-xai
# Processing Record 37 of Set 2 | tuktoyaktuk
# Processing Record 38 of Set 2 | saldanha
# Processing Record 39 of Set 2 | meadow lake
# Processing Record 40 of Set 2 | jamestown
# Processing Record 41 of Set 2 | narragansett
# Processing Record 42 of Set 2 | chanika
# Processing Record 43 of Set 2 | warri
# Processing Record 44 of Set 2 | kotma
# Processing Record 45 of Set 2 | clyde river
# Processing Record 46 of Set 2 | guerrero negro
# Processing Record 47 of Set 2 | boende
# Processing Record 48 of Set 2 | at-bashi
# Processing Record 49 of Set 2 | cocal
# Processing Record 50 of Set 2 | kununurra
# Processing Record 1 of Set 3 | tiksi
# Processing Record 2 of Set 3 | tura
# Processing Record 3 of Set 3 | chokurdakh
# Processing Record 4 of Set 3 | biltine
# Processing Record 5 of Set 3 | kapaa
# Processing Record 6 of Set 3 | tawkar
# City not found. Skipping...
# Processing Record 7 of Set 3 | prince rupert
# Processing Record 8 of Set 3 | belaya gora
# Processing Record 9 of Set 3 | nikolskoye
# Processing Record 10 of Set 3 | rawson
# Processing Record 11 of Set 3 | provideniya
# Processing Record 12 of Set 3 | coihaique
# Processing Record 13 of Set 3 | aanekoski
# Processing Record 14 of Set 3 | bogorodskoye
# Processing Record 15 of Set 3 | pacific grove
# Processing Record 16 of Set 3 | alofi
# Processing Record 17 of Set 3 | broken hill
# Processing Record 18 of Set 3 | saint-remi
# Processing Record 19 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 20 of Set 3 | san-pedro
# Processing Record 21 of Set 3 | urumqi
# Processing Record 22 of Set 3 | kadykchan
# City not found. Skipping...
# Processing Record 23 of Set 3 | airai
# Processing Record 24 of Set 3 | miastko
# Processing Record 25 of Set 3 | aguimes
# Processing Record 26 of Set 3 | dikson
# Processing Record 27 of Set 3 | mataura
# Processing Record 28 of Set 3 | sychevka
# Processing Record 29 of Set 3 | verkhoyansk
# Processing Record 30 of Set 3 | opunake
# Processing Record 31 of Set 3 | mayo
# Processing Record 32 of Set 3 | kodiak
# Processing Record 33 of Set 3 | bonavista
# Processing Record 34 of Set 3 | sao jose da coroa grande
# Processing Record 35 of Set 3 | dir
# Processing Record 36 of Set 3 | tual
# Processing Record 37 of Set 3 | xiuyan
# Processing Record 38 of Set 3 | barrow
# Processing Record 39 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 3 | otane
# Processing Record 41 of Set 3 | upernavik
# Processing Record 42 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 43 of Set 3 | cabedelo
# Processing Record 44 of Set 3 | qaanaaq
# Processing Record 45 of Set 3 | rochegda
# Processing Record 46 of Set 3 | magalia
# Processing Record 47 of Set 3 | cidreira
# Processing Record 48 of Set 3 | severnyy
# Processing Record 49 of Set 3 | oranjestad
# Processing Record 50 of Set 3 | natal
# Processing Record 1 of Set 4 | santa rosa
# Processing Record 2 of Set 4 | praia
# Processing Record 3 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 4 | port elizabeth
# Processing Record 5 of Set 4 | hovd
# Processing Record 6 of Set 4 | presidencia roque saenz pena
# Processing Record 7 of Set 4 | garissa
# Processing Record 8 of Set 4 | meulaboh
# Processing Record 9 of Set 4 | ocos
# Processing Record 10 of Set 4 | tasiilaq
# Processing Record 11 of Set 4 | buraydah
# Processing Record 12 of Set 4 | hami
# Processing Record 13 of Set 4 | kruisfontein
# Processing Record 14 of Set 4 | sao filipe
# Processing Record 15 of Set 4 | hermanus
# Processing Record 16 of Set 4 | north bend
# Processing Record 17 of Set 4 | mar del plata
# Processing Record 18 of Set 4 | todos santos
# Processing Record 19 of Set 4 | port-cartier
# Processing Record 20 of Set 4 | gurskoye
# City not found. Skipping...
# Processing Record 21 of Set 4 | hue
# Processing Record 22 of Set 4 | vestmannaeyjar
# Processing Record 23 of Set 4 | itarema
# Processing Record 24 of Set 4 | torbay
# Processing Record 25 of Set 4 | adrar
# Processing Record 26 of Set 4 | lewisville
# Processing Record 27 of Set 4 | chumikan
# Processing Record 28 of Set 4 | lumphat
# Processing Record 29 of Set 4 | magaria
# Processing Record 30 of Set 4 | ilulissat
# Processing Record 31 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 32 of Set 4 | komsomolskiy
# Processing Record 33 of Set 4 | burica
# City not found. Skipping...
# Processing Record 34 of Set 4 | oktyabrskiy
# Processing Record 35 of Set 4 | prescott
# Processing Record 36 of Set 4 | dingle
# Processing Record 37 of Set 4 | kaitangata
# Processing Record 38 of Set 4 | puerto del rosario
# Processing Record 39 of Set 4 | prainha
# Processing Record 40 of Set 4 | hibbing
# Processing Record 41 of Set 4 | phan rang
# City not found. Skipping...
# Processing Record 42 of Set 4 | benguela
# Processing Record 43 of Set 4 | las palmas
# Processing Record 44 of Set 4 | vaasa
# Processing Record 45 of Set 4 | tabou
# Processing Record 46 of Set 4 | san patricio
# Processing Record 47 of Set 4 | pangnirtung
# Processing Record 48 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 4 | hilo
# Processing Record 50 of Set 4 | longyearbyen
# Processing Record 1 of Set 5 | irondequoit
# Processing Record 2 of Set 5 | seoul
# Processing Record 3 of Set 5 | axim
# Processing Record 4 of Set 5 | severo-kurilsk
# Processing Record 5 of Set 5 | manzhouli
# Processing Record 6 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 5 | hamilton
# Processing Record 8 of Set 5 | nemuro
# Processing Record 9 of Set 5 | bontang
# Processing Record 10 of Set 5 | new norfolk
# Processing Record 11 of Set 5 | bilibino
# Processing Record 12 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 5 | hambantota
# Processing Record 14 of Set 5 | olinda
# Processing Record 15 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 5 | vanimo
# Processing Record 17 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 5 | mayor pablo lagerenza
# Processing Record 19 of Set 5 | luderitz
# Processing Record 20 of Set 5 | youkounkoun
# Processing Record 21 of Set 5 | hasaki
# Processing Record 22 of Set 5 | shaowu
# Processing Record 23 of Set 5 | mogadishu
# Processing Record 24 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 25 of Set 5 | ambilobe
# Processing Record 26 of Set 5 | tsaratanana
# Processing Record 27 of Set 5 | mersing
# Processing Record 28 of Set 5 | nome
# Processing Record 29 of Set 5 | matara
# Processing Record 30 of Set 5 | kalianget
# Processing Record 31 of Set 5 | bonthe
# Processing Record 32 of Set 5 | pesqueira
# Processing Record 33 of Set 5 | le port
# Processing Record 34 of Set 5 | kurchum
# Processing Record 35 of Set 5 | diamantina
# Processing Record 36 of Set 5 | bredasdorp
# Processing Record 37 of Set 5 | san jeronimo
# Processing Record 38 of Set 5 | dores do indaia
# Processing Record 39 of Set 5 | san policarpo
# Processing Record 40 of Set 5 | half moon bay
# Processing Record 41 of Set 5 | nouadhibou
# Processing Record 42 of Set 5 | walvis bay
# Processing Record 43 of Set 5 | charters towers
# Processing Record 44 of Set 5 | mimongo
# Processing Record 45 of Set 5 | pemberton
# Processing Record 46 of Set 5 | lavrentiya
# Processing Record 47 of Set 5 | sept-iles
# Processing Record 48 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 49 of Set 5 | san jose
# Processing Record 50 of Set 5 | kashi
# Processing Record 1 of Set 6 | mehamn
# Processing Record 2 of Set 6 | matale
# Processing Record 3 of Set 6 | bulgan
# Processing Record 4 of Set 6 | dhuwaran
# Processing Record 5 of Set 6 | beruwala
# Processing Record 6 of Set 6 | bani walid
# Processing Record 7 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 6 | codrington
# Processing Record 9 of Set 6 | ancud
# Processing Record 10 of Set 6 | faanui
# Processing Record 11 of Set 6 | ust-nera
# Processing Record 12 of Set 6 | husavik
# Processing Record 13 of Set 6 | sabinas hidalgo
# Processing Record 14 of Set 6 | kijang
# Processing Record 15 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 6 | donskoye
# Processing Record 17 of Set 6 | tanout
# Processing Record 18 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 19 of Set 6 | ust-ilimsk
# Processing Record 20 of Set 6 | turukhansk
# Processing Record 21 of Set 6 | zyryanka
# Processing Record 22 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 23 of Set 6 | zhaotong
# Processing Record 24 of Set 6 | aginskoye
# Processing Record 25 of Set 6 | souillac
# Processing Record 26 of Set 6 | gwadar
# Processing Record 27 of Set 6 | lebu
# Processing Record 28 of Set 6 | beloha
# Processing Record 29 of Set 6 | ilebo
# Processing Record 30 of Set 6 | kahului
# Processing Record 31 of Set 6 | ronne
# Processing Record 32 of Set 6 | narsaq
# Processing Record 33 of Set 6 | shache
# Processing Record 34 of Set 6 | morehead
# Processing Record 35 of Set 6 | acarau
# Processing Record 36 of Set 6 | ilhabela
# Processing Record 37 of Set 6 | burnie
# Processing Record 38 of Set 6 | kilindoni
# Processing Record 39 of Set 6 | sioux lookout
# Processing Record 40 of Set 6 | bud
# Processing Record 41 of Set 6 | anloga
# Processing Record 42 of Set 6 | pitimbu
# Processing Record 43 of Set 6 | vila franca do campo
# Processing Record 44 of Set 6 | bethel
# Processing Record 45 of Set 6 | yuksekova
# Processing Record 46 of Set 6 | noumea
# Processing Record 47 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 6 | kabwe
# Processing Record 49 of Set 6 | olafsvik
# Processing Record 50 of Set 6 | omagari
# Processing Record 1 of Set 7 | ulverstone
# Processing Record 2 of Set 7 | progreso
# Processing Record 3 of Set 7 | darhan
# Processing Record 4 of Set 7 | iqaluit
# Processing Record 5 of Set 7 | chom bung
# City not found. Skipping...
# Processing Record 6 of Set 7 | cao bang
# Processing Record 7 of Set 7 | poum
# Processing Record 8 of Set 7 | sarakhs
# Processing Record 9 of Set 7 | margate
# Processing Record 10 of Set 7 | xiongshi
# City not found. Skipping...
# Processing Record 11 of Set 7 | manavalakurichi
# Processing Record 12 of Set 7 | ahar
# Processing Record 13 of Set 7 | chake chake
# Processing Record 14 of Set 7 | fuyu
# Processing Record 15 of Set 7 | paamiut
# Processing Record 16 of Set 7 | ribeira grande
# Processing Record 17 of Set 7 | saint-francois
# Processing Record 18 of Set 7 | sawakin
# Processing Record 19 of Set 7 | kropotkin
# Processing Record 20 of Set 7 | prokuplje
# Processing Record 21 of Set 7 | tuburan
# Processing Record 22 of Set 7 | ahumada
# City not found. Skipping...
# Processing Record 23 of Set 7 | karamea
# City not found. Skipping...
# Processing Record 24 of Set 7 | northam
# Processing Record 25 of Set 7 | laguna
# Processing Record 26 of Set 7 | saint george
# Processing Record 27 of Set 7 | koygorodok
# Processing Record 28 of Set 7 | sobolevo
# Processing Record 29 of Set 7 | tutoia
# Processing Record 30 of Set 7 | sulangan
# Processing Record 31 of Set 7 | maumere
# Processing Record 32 of Set 7 | taltal
# Processing Record 33 of Set 7 | aybak
# City not found. Skipping...
# Processing Record 34 of Set 7 | octeville
# Processing Record 35 of Set 7 | sofiysk
# City not found. Skipping...
# Processing Record 36 of Set 7 | mangit
# Processing Record 37 of Set 7 | panguna
# Processing Record 38 of Set 7 | kayerkan
# Processing Record 39 of Set 7 | tuatapere
# Processing Record 40 of Set 7 | caraballeda
# Processing Record 41 of Set 7 | warrnambool
# Processing Record 42 of Set 7 | roebourne
# Processing Record 43 of Set 7 | pochutla
# Processing Record 44 of Set 7 | belidzhi
# Processing Record 45 of Set 7 | skibotn
# Processing Record 46 of Set 7 | mahebourg
# Processing Record 47 of Set 7 | balsas
# Processing Record 48 of Set 7 | san quintin
# Processing Record 49 of Set 7 | svobodnyy
# Processing Record 50 of Set 7 | waingapu
# Processing Record 1 of Set 8 | vila velha
# Processing Record 2 of Set 8 | ostrovnoy
# Processing Record 3 of Set 8 | awbari
# Processing Record 4 of Set 8 | klaksvik
# Processing Record 5 of Set 8 | katangli
# Processing Record 6 of Set 8 | namatanai
# Processing Record 7 of Set 8 | agadez
# Processing Record 8 of Set 8 | morris
# Processing Record 9 of Set 8 | portland
# Processing Record 10 of Set 8 | ixtapa
# Processing Record 11 of Set 8 | marsh harbour
# Processing Record 12 of Set 8 | viseu
# Processing Record 13 of Set 8 | panzhihua
# Processing Record 14 of Set 8 | sambava
# Processing Record 15 of Set 8 | joshimath
# Processing Record 16 of Set 8 | areia branca
# Processing Record 17 of Set 8 | camanducaia
# Processing Record 18 of Set 8 | scottsbluff
# Processing Record 19 of Set 8 | jalu
# Processing Record 20 of Set 8 | lasa
# Processing Record 21 of Set 8 | sarahan
# Processing Record 22 of Set 8 | aktas
# Processing Record 23 of Set 8 | dickson
# Processing Record 24 of Set 8 | najran
# Processing Record 25 of Set 8 | sistranda
# Processing Record 26 of Set 8 | matay
# Processing Record 27 of Set 8 | loubomo
# Processing Record 28 of Set 8 | latehar
# Processing Record 29 of Set 8 | raga
# Processing Record 30 of Set 8 | sabha
# Processing Record 31 of Set 8 | aksarka
# Processing Record 32 of Set 8 | raglan
# Processing Record 33 of Set 8 | snasa
# Processing Record 34 of Set 8 | el alto
# Processing Record 35 of Set 8 | hong gai
# Processing Record 36 of Set 8 | brae
# Processing Record 37 of Set 8 | aransas pass
# Processing Record 38 of Set 8 | maragogi
# Processing Record 39 of Set 8 | gat
# Processing Record 40 of Set 8 | kalikino
# Processing Record 41 of Set 8 | batemans bay
# Processing Record 42 of Set 8 | owando
# Processing Record 43 of Set 8 | coahuayana
# Processing Record 44 of Set 8 | necochea
# Processing Record 45 of Set 8 | baykit
# Processing Record 46 of Set 8 | bengkulu
# Processing Record 47 of Set 8 | iraucuba
# Processing Record 48 of Set 8 | cardston
# Processing Record 49 of Set 8 | kualakapuas
# Processing Record 50 of Set 8 | haines junction
# Processing Record 1 of Set 9 | flin flon
# Processing Record 2 of Set 9 | finote selam
# Processing Record 3 of Set 9 | novoagansk
# Processing Record 4 of Set 9 | goderich
# Processing Record 5 of Set 9 | burkhala
# City not found. Skipping...
# Processing Record 6 of Set 9 | wittstock
# Processing Record 7 of Set 9 | norman wells
# Processing Record 8 of Set 9 | vestmanna
# Processing Record 9 of Set 9 | tilichiki
# Processing Record 10 of Set 9 | mayumba
# Processing Record 11 of Set 9 | oriximina
# Processing Record 12 of Set 9 | roald
# Processing Record 13 of Set 9 | akdepe
# Processing Record 14 of Set 9 | iralaya
# Processing Record 15 of Set 9 | puerto escondido
# Processing Record 16 of Set 9 | izhma
# Processing Record 17 of Set 9 | kavieng
# Processing Record 18 of Set 9 | daokou
# Processing Record 19 of Set 9 | xining
# Processing Record 20 of Set 9 | touros
# Processing Record 21 of Set 9 | totness
# Processing Record 22 of Set 9 | mergui
# City not found. Skipping...
# Processing Record 23 of Set 9 | bay roberts
# Processing Record 24 of Set 9 | tessalit
# Processing Record 25 of Set 9 | mana
# Processing Record 26 of Set 9 | grindavik
# Processing Record 27 of Set 9 | esperance
# Processing Record 28 of Set 9 | ati
# Processing Record 29 of Set 9 | roswell
# Processing Record 30 of Set 9 | mount gambier
# Processing Record 31 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 32 of Set 9 | bathsheba
# Processing Record 33 of Set 9 | salaga
# Processing Record 34 of Set 9 | kathmandu
# Processing Record 35 of Set 9 | huangzhai
# Processing Record 36 of Set 9 | salalah
# Processing Record 37 of Set 9 | ninotsminda
# Processing Record 38 of Set 9 | gambela
# Processing Record 39 of Set 9 | khash
# Processing Record 40 of Set 9 | hulan ergi
# Processing Record 41 of Set 9 | isfana
# Processing Record 42 of Set 9 | leningradskiy
# Processing Record 43 of Set 9 | nalut
# Processing Record 44 of Set 9 | namibe
# Processing Record 45 of Set 9 | tezu
# Processing Record 46 of Set 9 | tamano
# Processing Record 47 of Set 9 | panalingaan
# Processing Record 48 of Set 9 | bubaque
# Processing Record 49 of Set 9 | hoa binh
# Processing Record 50 of Set 9 | fairbanks
# Processing Record 1 of Set 10 | gobabis
# Processing Record 2 of Set 10 | balkhash
# Processing Record 3 of Set 10 | aklavik
# Processing Record 4 of Set 10 | port macquarie
# Processing Record 5 of Set 10 | dutse
# Processing Record 6 of Set 10 | buala
# Processing Record 7 of Set 10 | erzin
# Processing Record 8 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 9 of Set 10 | sitka
# Processing Record 10 of Set 10 | kamenka
# Processing Record 11 of Set 10 | eureka
# Processing Record 12 of Set 10 | ponta do sol
# Processing Record 13 of Set 10 | kismayo
# Processing Record 14 of Set 10 | sibolga
# Processing Record 15 of Set 10 | udachnyy
# Processing Record 16 of Set 10 | tanhacu
# Processing Record 17 of Set 10 | sorland
# Processing Record 18 of Set 10 | praia da vitoria
# Processing Record 19 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 20 of Set 10 | te anau
# Processing Record 21 of Set 10 | zhigansk
# Processing Record 22 of Set 10 | primorsk
# Processing Record 23 of Set 10 | kenai
# Processing Record 24 of Set 10 | mumford
# Processing Record 25 of Set 10 | champerico
# Processing Record 26 of Set 10 | mount abu
# Processing Record 27 of Set 10 | tamazulapam
# City not found. Skipping...
# Processing Record 28 of Set 10 | changji
# Processing Record 29 of Set 10 | sisimiut
# Processing Record 30 of Set 10 | salinopolis
# Processing Record 31 of Set 10 | ahipara
# Processing Record 32 of Set 10 | iquique
# Processing Record 33 of Set 10 | grants pass
# Processing Record 34 of Set 10 | chepen
# Processing Record 35 of Set 10 | harper
# Processing Record 36 of Set 10 | nizhniy odes
# Processing Record 37 of Set 10 | semirom
# Processing Record 38 of Set 10 | tateyama
# Processing Record 39 of Set 10 | cenade
# Processing Record 40 of Set 10 | lisakovsk
# Processing Record 41 of Set 10 | undory
# Processing Record 42 of Set 10 | saint-joseph
# Processing Record 43 of Set 10 | voi
# Processing Record 44 of Set 10 | belaya glina
# Processing Record 45 of Set 10 | corrente
# Processing Record 46 of Set 10 | mata de sao joao
# Processing Record 47 of Set 10 | vostok
# Processing Record 48 of Set 10 | balkanabat
# Processing Record 49 of Set 10 | berbera
# Processing Record 50 of Set 10 | marienburg
# Processing Record 1 of Set 11 | klamath falls
# Processing Record 2 of Set 11 | bocas del toro
# Processing Record 3 of Set 11 | ancona
# Processing Record 4 of Set 11 | estacion coahuila
# Processing Record 5 of Set 11 | antofagasta
# Processing Record 6 of Set 11 | freeport
# Processing Record 7 of Set 11 | pakxan
# Processing Record 8 of Set 11 | maniitsoq
# Processing Record 9 of Set 11 | saint stephen
# Processing Record 10 of Set 11 | aswan
# Processing Record 11 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 11 | gao
# Processing Record 13 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 11 | kita
# Processing Record 15 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 16 of Set 11 | lata
# Processing Record 17 of Set 11 | evensk
# Processing Record 18 of Set 11 | raudeberg
# Processing Record 19 of Set 11 | zaozerne
# Processing Record 20 of Set 11 | plettenberg bay
# Processing Record 21 of Set 11 | azrow
# City not found. Skipping...
# Processing Record 22 of Set 11 | cayenne
# Processing Record 23 of Set 11 | hobyo
# Processing Record 24 of Set 11 | tabasalu
# Processing Record 25 of Set 11 | betlitsa
# Processing Record 26 of Set 11 | beipiao
# Processing Record 27 of Set 11 | kashan
# Processing Record 28 of Set 11 | bandarbeyla
# Processing Record 29 of Set 11 | skelleftea
# Processing Record 30 of Set 11 | porto nacional
# Processing Record 31 of Set 11 | constitucion
# Processing Record 32 of Set 11 | linhares
# Processing Record 33 of Set 11 | neuquen
# Processing Record 34 of Set 11 | mulege
# Processing Record 35 of Set 11 | svencioneliai
# Processing Record 36 of Set 11 | port-gentil
# Processing Record 37 of Set 11 | kendari
# Processing Record 38 of Set 11 | las vegas
# Processing Record 39 of Set 11 | chaa-khol
# City not found. Skipping...
# Processing Record 40 of Set 11 | nantucket
# Processing Record 41 of Set 11 | sao joao da barra
# Processing Record 42 of Set 11 | iquitos
# Processing Record 43 of Set 11 | sorong
# Processing Record 44 of Set 11 | alice springs
# Processing Record 45 of Set 11 | dire
# Processing Record 46 of Set 11 | north platte
# Processing Record 47 of Set 11 | santo antonio do monte
# Processing Record 48 of Set 11 | port hedland
# Processing Record 49 of Set 11 | nicoya
# Processing Record 50 of Set 11 | verkh-usugli
# Processing Record 1 of Set 12 | cabo san lucas
# Processing Record 2 of Set 12 | omsukchan
# Processing Record 3 of Set 12 | harij
# Processing Record 4 of Set 12 | bukachacha
# Processing Record 5 of Set 12 | boa vista
# Processing Record 6 of Set 12 | hay river
# Processing Record 7 of Set 12 | caldas da rainha
# Processing Record 8 of Set 12 | srednekolymsk
# Processing Record 9 of Set 12 | felipe carrillo puerto
# Processing Record 10 of Set 12 | vila
# Processing Record 11 of Set 12 | mercedes
# Processing Record 12 of Set 12 | muravlenko
# Processing Record 13 of Set 12 | kosino
# Processing Record 14 of Set 12 | guajara-mirim
# City not found. Skipping...
# Processing Record 15 of Set 12 | dzhebariki-khaya
# Processing Record 16 of Set 12 | korem
# Processing Record 17 of Set 12 | beringovskiy
# Processing Record 18 of Set 12 | loreto
# Processing Record 19 of Set 12 | hanzhong
# Processing Record 20 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 21 of Set 12 | nueva gerona
# Processing Record 22 of Set 12 | oussouye
# Processing Record 23 of Set 12 | tahe
# Processing Record 24 of Set 12 | rabat
# Processing Record 25 of Set 12 | kabin buri
# Processing Record 26 of Set 12 | iwaki
# Processing Record 27 of Set 12 | buin
# Processing Record 28 of Set 12 | greytown
# Processing Record 29 of Set 12 | panjab
# Processing Record 30 of Set 12 | magway
# Processing Record 31 of Set 12 | port lincoln
# Processing Record 32 of Set 12 | la ronge
# Processing Record 33 of Set 12 | dunedin
# Processing Record 34 of Set 12 | may pen
# Processing Record 35 of Set 12 | kango
# Processing Record 36 of Set 12 | kamaishi
# Processing Record 37 of Set 12 | urucara
# Processing Record 38 of Set 12 | leo
# Processing Record 39 of Set 12 | ishigaki
# Processing Record 40 of Set 12 | albanel
# Processing Record 41 of Set 12 | alpena
# Processing Record 42 of Set 12 | ayolas
# Processing Record 43 of Set 12 | marsa matruh
# Processing Record 44 of Set 12 | remontnoye
# Processing Record 45 of Set 12 | ponta delgada
# Processing Record 46 of Set 12 | mujiayingzi
# Processing Record 47 of Set 12 | weligama
# Processing Record 48 of Set 12 | sindou
# Processing Record 49 of Set 12 | lensk
# Processing Record 50 of Set 12 | ossora
# Processing Record 1 of Set 13 | bokspits
# City not found. Skipping...
# Processing Record 2 of Set 13 | noyabrsk
# Processing Record 3 of Set 13 | los llanos de aridane
# Processing Record 4 of Set 13 | la romana
# Processing Record 5 of Set 13 | marawi
# Processing Record 6 of Set 13 | zirandaro
# Processing Record 7 of Set 13 | havelock
# Processing Record 8 of Set 13 | murska sobota
# Processing Record 9 of Set 13 | tongzi
# Processing Record 10 of Set 13 | bangkal
# Processing Record 11 of Set 13 | bodden town
# Processing Record 12 of Set 13 | aranos
# Processing Record 13 of Set 13 | nordfjordeid
# Processing Record 14 of Set 13 | porto novo
# Processing Record 15 of Set 13 | guasdualito
# Processing Record 16 of Set 13 | shilka
# Processing Record 17 of Set 13 | ketchikan
# Processing Record 18 of Set 13 | swedru
# Processing Record 19 of Set 13 | krasnoselkup
# Processing Record 20 of Set 13 | veydelevka
# Processing Record 21 of Set 13 | zhangye
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0               Bluff -46.6000  168.3333     52.81        78         100
# 1              Padang  -0.9492  100.3543     82.45        74         100
# 2  Severo-Yeniseyskiy  60.3725   93.0408     31.37        89         100
# 3              Tommot  58.9564  126.2925     37.40        64          23
# 4                Hofn  64.2539  -15.2082     44.96        79         100
# 5          Butaritari   3.0707  172.7902     82.96        68           7
# 6        Puerto Ayora  -0.7393  -90.3518     69.40        86          60
# 7         Yellowknife  62.4560 -114.3525     44.42        62          20
# 8       Murray Bridge -35.1167  139.2667     58.42        54          28
# 9              Wairoa -39.0333  177.3667     65.55        80         100
#
#    Wind Speed Country                 Date
# 0       25.88      NZ  2021-10-04 02:36:44
# 1        3.04      ID  2021-10-04 02:36:45
# 2        3.36      RU  2021-10-04 02:36:45
# 3        5.97      RU  2021-10-04 02:36:46
# 4       21.27      IS  2021-10-04 02:36:46
# 5       16.69      KI  2021-10-04 02:36:46
# 6       10.51      EC  2021-10-04 02:36:47
# 7        6.91      CA  2021-10-04 02:36:47
# 8       27.22      AU  2021-10-04 02:36:47
# 9        5.01      NZ  2021-10-04 02:36:48

# %%
column_adjust = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[column_adjust]
city_data_df.head()
# Out:
#                  City Country                 Date      Lat       Lng  \
# 0               Bluff      NZ  2021-10-04 02:36:44 -46.6000  168.3333
# 1              Padang      ID  2021-10-04 02:36:45  -0.9492  100.3543
# 2  Severo-Yeniseyskiy      RU  2021-10-04 02:36:45  60.3725   93.0408
# 3              Tommot      RU  2021-10-04 02:36:46  58.9564  126.2925
# 4                Hofn      IS  2021-10-04 02:36:46  64.2539  -15.2082
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     52.81        78         100       25.88
# 1     82.45        74         100        3.04
# 2     31.37        89         100        3.36
# 3     37.40        64          23        5.97
# 4     44.96        79         100       21.27

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()
